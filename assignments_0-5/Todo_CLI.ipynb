# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddique02/project_4_assignments/blob/main/assignments_0-5/Todo_CLI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
TODO_LIST = []

def show_todos():
  if not TODO_LIST:
    print("No todos found")
  else:
    for index, item in enumerate(TODO_LIST):
      print(f"{index + 1}. {item}")

def add_task():
  task = input("Enter a task: ")
  TODO_LIST.append(task)
  print("Task addded!")

def delete_task():
  show_todos()
  try:
    task_num = int(input("Enter the task number to delete: "))
    if 1 <= task_num <= len(TODO_LIST):
      del TODO_LIST[task_num - 1]
    else:
      print("Invalid task number")
  except ValueError:
    print("Invalid input. Please enter a number.")

def todo_app():
  while True:
    print("\n===== Todo App =====")
    print("1. Show Todos")
    print("2. Add Task")
    print("3. Delete Task")
    print("4. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
      show_todos()
    elif choice == "2":
      add_task()
    elif choice == "3":
      delete_task()
    elif choice == "4":
      print("Exiting!!!")
      break
    else:
      print("Invalid choice. Please try again.")


if __name__ == "__main__":
  todo_app()
# Out:
# ===== Todo App =====
# 1. Show Todos
# 2. Add Task
# 3. Delete Task
# 4. Exit
# Enter your choice: 2
# Enter a task: Nike k jootay
# Task addded!
#
# ===== Todo App =====
# 1. Show Todos
# 2. Add Task
# 3. Delete Task
# 4. Exit
# Enter your choice: 1
# 1. Nike k jootay
#
# ===== Todo App =====
# 1. Show Todos
# 2. Add Task
# 3. Delete Task
# 4. Exit
# Enter your choice: 1
# 1. Nike k jootay
#
# ===== Todo App =====
# 1. Show Todos
# 2. Add Task
# 3. Delete Task
# 4. Exit
# Enter your choice: 2
# Enter a task: slkdjflksjflks
# Task addded!
#
# ===== Todo App =====
# 1. Show Todos
# 2. Add Task
# 3. Delete Task
# 4. Exit
# Enter your choice: 2
# Enter a task: sjdlfjsdfklsj
# Task addded!
#
# ===== Todo App =====
# 1. Show Todos
# 2. Add Task
# 3. Delete Task
# 4. Exit
# Enter your choice: 2
# Enter a task: etnbnenovooer5784
# Task addded!
#
# ===== Todo App =====
# 1. Show Todos
# 2. Add Task
# 3. Delete Task
# 4. Exit
# Enter your choice: 1
# 1. Nike k jootay
# 2. slkdjflksjflks
# ...
